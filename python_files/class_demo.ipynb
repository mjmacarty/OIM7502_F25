# %%
from stock import Stock

# %%
aapl = Stock("AAPL")
# Out:
# ...
# Data successfully downloaded and returns calculated for AAPL.
# C:\Users\mmacarty\OneDrive\Babson\OIM7502\git_files\OIM7502_F25\python_files\stock.py:55: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.symbol, start=self.start, end=self.end, progress=False)

# %%
aapl.data
# Out:
# Price            Close        High         Low        Open    Volume  change  \
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-10-14  230.228516  230.656516  227.541026  227.640554  39882100     NaN
# 2024-10-15  232.766708  236.389846  231.293553  232.527815  64751400  0.0110
# 2024-10-16  230.706268  231.044690  228.775253  230.527109  34082200 -0.0089
# 2024-10-17  231.074570  232.766707  229.452131  232.348639  32993800  0.0016
# 2024-10-18  233.911362  235.085888  232.925942  235.085888  46431500  0.0123
# ...                ...         ...         ...         ...       ...     ...
# 2025-10-07  256.480011  257.399994  255.429993  256.809998  31955800 -0.0008
# 2025-10-08  258.059998  258.519989  256.109985  256.519989  36496900  0.0062
# 2025-10-09  254.039993  258.000000  253.139999  257.809998  38322000 -0.0156
# 2025-10-10  245.270004  256.380005  244.000000  254.940002  61999100 -0.0345
# ...

# %%
f = Stock("F")
# Out:
# ...
# C:\Users\mmacarty\OneDrive\Babson\OIM7502\git_files\OIM7502_F25\python_files\stock.py:55: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.symbol, start=self.start, end=self.end, progress=False)
# Data successfully downloaded and returns calculated for F.

# %%
f.plot_performance()

# %%
f.plot_return_dist()

# %%
aapl.plot_return_dist()
